# %% [markdown]
# ## DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc 
import seaborn as sns
import time

# %%
plt.rc('font', family='AppleGothic')

# %%
df = pd.read_csv('상권변화지표.csv', thousands=',', encoding='euc-kr').drop(['Unnamed: 0'], axis=1)
df
# Out:
#        년도  분기 행정구역  개업률  폐업률  신생 1  생존률  신생 3  생존률  신생 5  생존률  1  생존률  3  생존률  \
# 0    2016   3  종로구  3.9  4.3       74.7       46.8       30.2    73.7    45.5
# 1    2016   3   중구  3.5  3.9       73.0       47.4       37.3    78.4    52.3
# 2    2016   3  용산구  4.6  4.6       74.3       44.3       33.4    72.6    46.7
# 3    2016   3  성동구  5.2  5.2       67.4       46.8       31.5    74.4    47.1
# 4    2016   3  광진구  4.4  5.1       71.4       38.4       26.4    71.8    40.9
# ..    ...  ..  ...  ...  ...        ...        ...        ...     ...     ...
# 495  2021   2  관악구  5.3  4.7       73.3       42.3       23.5    64.2    36.9
# 496  2021   2  서초구  3.6  3.2       76.8       51.0       31.5    70.8    44.9
# 497  2021   2  강남구  4.8  3.5       74.2       45.0       27.9    66.5    39.2
# 498  2021   2  송파구  4.6  4.0       70.7       44.7       29.3    69.8    42.4
# 499  2021   2  강동구  5.1  4.4       73.1       42.6       26.0    66.8    38.5
#
#      5  생존률  주거 인구  직장 인구     임대료  전체 점포수  프랜차이즈 점포수  일반 점포수  최근 10년  평균영업기간  \
# 0      31.3     62    125  142788    7088        958    6130             3.1
# 1      37.4    110    517  188434    6683       1079    5604             3.2
# 2      32.1     97     72  100920    4909        638    4271             3.0
# 3      32.3    150    101   85570    3807        675    3132             3.0
# 4      25.4    197     45   88334    5216        975    4241             3.0
# ..      ...    ...    ...     ...     ...        ...     ...             ...
# 495    27.4    166     25  108356    6135       1072    5063             2.4
# 496    34.0     89    121  123724    7948       1500    6448             2.8
# 497    30.1    141    293  144055   13772       2561   11211             2.6
# 498    31.7    199    119  154301    8673       1783    6890             2.5
# 499    30.2    180     29  106463    5598       1057    4541             2.5
#
#      최근 30년  평균영업기간 상권변화지표
# 0               5.1     정체
# 1               5.3     정체
# 2               4.7     정체
# 3               4.7     정체
# 4               4.5   다이나믹
# ..              ...    ...
# 495             4.4   다이나믹
# 496             4.8     정체
# 497             4.4   다이나믹
# 498             4.4   다이나믹
# 499             4.4   다이나믹
#
# [500 rows x 20 columns]

# %%
a = df['상권변화지표']
df['프랜차이즈 점포 비율'] = df['프랜차이즈 점포수'] / df['전체 점포수']
df['직장 인구 대비 주거 인구'] = df['직장 인구'] / df['주거 인구']
df = df.drop(['전체 점포수', '프랜차이즈 점포수', '일반 점포수', '상권변화지표', '직장 인구', '주거 인구'], axis=1)
df['상권변화지표'] = a
df
# Out:
#        년도  분기 행정구역  개업률  폐업률  신생 1  생존률  신생 3  생존률  신생 5  생존률  1  생존률  3  생존률  \
# 0    2016   3  종로구  3.9  4.3       74.7       46.8       30.2    73.7    45.5
# 1    2016   3   중구  3.5  3.9       73.0       47.4       37.3    78.4    52.3
# 2    2016   3  용산구  4.6  4.6       74.3       44.3       33.4    72.6    46.7
# 3    2016   3  성동구  5.2  5.2       67.4       46.8       31.5    74.4    47.1
# 4    2016   3  광진구  4.4  5.1       71.4       38.4       26.4    71.8    40.9
# ..    ...  ..  ...  ...  ...        ...        ...        ...     ...     ...
# 495  2021   2  관악구  5.3  4.7       73.3       42.3       23.5    64.2    36.9
# 496  2021   2  서초구  3.6  3.2       76.8       51.0       31.5    70.8    44.9
# 497  2021   2  강남구  4.8  3.5       74.2       45.0       27.9    66.5    39.2
# 498  2021   2  송파구  4.6  4.0       70.7       44.7       29.3    69.8    42.4
# 499  2021   2  강동구  5.1  4.4       73.1       42.6       26.0    66.8    38.5
#
#      5  생존률     임대료  최근 10년  평균영업기간  최근 30년  평균영업기간  프랜차이즈 점포 비율  \
# 0      31.3  142788             3.1             5.1     0.135158
# 1      37.4  188434             3.2             5.3     0.161454
# 2      32.1  100920             3.0             4.7     0.129965
# 3      32.3   85570             3.0             4.7     0.177305
# 4      25.4   88334             3.0             4.5     0.186925
# ..      ...     ...             ...             ...          ...
# 495    27.4  108356             2.4             4.4     0.174735
# 496    34.0  123724             2.8             4.8     0.188727
# 497    30.1  144055             2.6             4.4     0.185957
# 498    31.7  154301             2.5             4.4     0.205581
# 499    30.2  106463             2.5             4.4     0.188817
#
#      직장 인구 대비 주거 인구 상권변화지표
# 0          2.016129     정체
# 1          4.700000     정체
# 2          0.742268     정체
# 3          0.673333     정체
# 4          0.228426   다이나믹
# ..              ...    ...
# 495        0.150602   다이나믹
# 496        1.359551     정체
# 497        2.078014   다이나믹
# 498        0.597990   다이나믹
# 499        0.161111   다이나믹
#
# [500 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['년도', '분기', '행정구역', '개업률', '폐업률', '신생 1  생존률', '신생 3  생존률', '신생 5  생존률',
#        '1  생존률', '3  생존률', '5  생존률', '임대료', '최근 10년  평균영업기간', '최근 30년  평균영업기간',
#        '프랜차이즈 점포 비율', '직장 인구 대비 주거 인구', '상권변화지표'],
#       dtype='object')

# %%
columns = ['개업률', '폐업률', '신생 1  생존률', '신생 3  생존률', '신생 5  생존률',
       '1  생존률', '3  생존률', '5  생존률', '임대료', '최근 10년  평균영업기간', '최근 30년  평균영업기간',
       '프랜차이즈 점포 비율', '직장 인구 대비 주거 인구']
df1 = pd.DataFrame(df, columns=columns)
df1['target'] = df['상권변화지표']
df1
# Out:
#      개업률  폐업률  신생 1  생존률  신생 3  생존률  신생 5  생존률  1  생존률  3  생존률  5  생존률  \
# 0    3.9  4.3       74.7       46.8       30.2    73.7    45.5    31.3
# 1    3.5  3.9       73.0       47.4       37.3    78.4    52.3    37.4
# 2    4.6  4.6       74.3       44.3       33.4    72.6    46.7    32.1
# 3    5.2  5.2       67.4       46.8       31.5    74.4    47.1    32.3
# 4    4.4  5.1       71.4       38.4       26.4    71.8    40.9    25.4
# ..   ...  ...        ...        ...        ...     ...     ...     ...
# 495  5.3  4.7       73.3       42.3       23.5    64.2    36.9    27.4
# 496  3.6  3.2       76.8       51.0       31.5    70.8    44.9    34.0
# 497  4.8  3.5       74.2       45.0       27.9    66.5    39.2    30.1
# 498  4.6  4.0       70.7       44.7       29.3    69.8    42.4    31.7
# 499  5.1  4.4       73.1       42.6       26.0    66.8    38.5    30.2
#
#         임대료  최근 10년  평균영업기간  최근 30년  평균영업기간  프랜차이즈 점포 비율  직장 인구 대비 주거 인구  \
# 0    142788             3.1             5.1     0.135158        2.016129
# 1    188434             3.2             5.3     0.161454        4.700000
# 2    100920             3.0             4.7     0.129965        0.742268
# 3     85570             3.0             4.7     0.177305        0.673333
# 4     88334             3.0             4.5     0.186925        0.228426
# ..      ...             ...             ...          ...             ...
# 495  108356             2.4             4.4     0.174735        0.150602
# 496  123724             2.8             4.8     0.188727        1.359551
# 497  144055             2.6             4.4     0.185957        2.078014
# 498  154301             2.5             4.4     0.205581        0.597990
# 499  106463             2.5             4.4     0.188817        0.161111
#
#     target
# 0       정체
# 1       정체
# 2       정체
# 3       정체
# 4     다이나믹
# ..     ...
# 495   다이나믹
# 496     정체
# 497   다이나믹
# 498   다이나믹
# 499   다이나믹
#
# [500 rows x 14 columns]

# %%
X = df1.iloc[:, :-1]
Y = df1.iloc[:, -1]

# %% [markdown]
# ## 상관관계

# %%
corr = X.corr()
plt.figure(figsize=(9,9))
ax = sns.heatmap(corr, annot=True, cmap='gray')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
corr = corr.apply(lambda x: round(x, 2))
s = corr.unstack()
df_corr = pd.DataFrame(s[s < 1].sort_values(ascending=False), columns=['상관계수'])
df_corr.style.background_gradient(cmap='gray')
# Out:
# <style  type="text/css" >
# #T_775f6924_51a7_11ec_945b_1e009a147665row0_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row1_col0{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row2_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row3_col0{
#             background-color:  #fefefe;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row4_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row5_col0{
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row6_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row7_col0{
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row8_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row9_col0{
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row10_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row11_col0{
#             background-color:  #f1f1f1;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row12_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row13_col0{
#             background-color:  #f0f0f0;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row14_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row15_col0{
#             background-color:  #eeeeee;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row16_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row17_col0{
#             background-color:  #ebebeb;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row18_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row19_col0{
#             background-color:  #e8e8e8;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row20_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row21_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row22_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row23_col0{
#             background-color:  #e3e3e3;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row24_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row25_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row26_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row27_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row28_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row29_col0{
#             background-color:  #e1e1e1;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row30_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row31_col0{
#             background-color:  #dddddd;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row32_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row33_col0{
#             background-color:  #dbdbdb;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row34_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row35_col0{
#             background-color:  #d8d8d8;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row36_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row37_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row38_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row39_col0{
#             background-color:  #d6d6d6;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row40_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row41_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row42_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row43_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row44_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row45_col0{
#             background-color:  #d3d3d3;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row46_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row47_col0{
#             background-color:  #d0d0d0;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row48_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row49_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row50_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row51_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row52_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row53_col0{
#             background-color:  #cdcdcd;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row54_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row55_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row56_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row57_col0{
#             background-color:  #cbcbcb;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row58_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row59_col0{
#             background-color:  #c8c8c8;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row60_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row61_col0{
#             background-color:  #c7c7c7;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row62_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row63_col0{
#             background-color:  #c5c5c5;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row64_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row65_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row66_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row67_col0{
#             background-color:  #c3c3c3;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row68_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row69_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row70_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row71_col0{
#             background-color:  #c0c0c0;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row72_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row73_col0{
#             background-color:  #bababa;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row74_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row75_col0{
#             background-color:  #b8b8b8;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row76_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row77_col0{
#             background-color:  #b5b5b5;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row78_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row79_col0{
#             background-color:  #b4b4b4;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row80_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row81_col0{
#             background-color:  #adadad;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row82_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row83_col0{
#             background-color:  #a5a5a5;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row84_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row85_col0{
#             background-color:  #a4a4a4;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row86_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row87_col0{
#             background-color:  #9c9c9c;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row88_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row89_col0{
#             background-color:  #919191;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row90_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row91_col0{
#             background-color:  #818181;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row92_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row93_col0{
#             background-color:  #7c7c7c;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row94_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row95_col0{
#             background-color:  #797979;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row96_col0,#T_775f6924_51a7_11ec_945b_1e009a147665row97_col0{
#             background-color:  #6e6e6e;
#             color:  #000000;
#         }#T_775f6924_51a7_11ec_945b_1e009a147665row98_col0,#T_775f6924_51a7_11ec_945b_1e009

# %% [markdown]
# 생존률 간의 높은 상관관계

# %% [markdown]
# ## 변수 선택

# %%
from sklearn.preprocessing import StandardScaler

X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[-0.66823582, -0.08949949,  1.04039609, ...,  2.14731753,
#         -1.8220577 ,  1.75526197],
#        [-1.18206574, -0.62223452,  0.53904302, ...,  2.90394809,
#         -0.69917054,  5.12009732],
#        [ 0.23096655,  0.31005179,  0.92243066, ...,  0.63405641,
#         -2.0437895 ,  0.15819097],
#        ...,
#        [ 0.48788151, -1.15496956,  0.89293931, ..., -0.50088943,
#          0.34711738,  1.83284891],
#        [ 0.23096655, -0.48905076, -0.13925819, ..., -0.50088943,
#          1.18506412, -0.02269404],
#        [ 0.87325396,  0.04368427,  0.56853438, ..., -0.50088943,
#          0.46926059, -0.57041984]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier

# %%
data_train = X_scaled[:450]
target_train = Y[:450]
data_test = X_scaled[450:]
target_test = Y[450:]

x_train, x_val, y_train, y_val = train_test_split(data_train, target_train, test_size=0.2)

x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((360, 13), (90, 13), (360,), (90,))

# %%
rf = RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)
scores = cross_validate(rf, x_train, y_train, return_train_score=True, n_jobs=-1)
print(np.mean(scores['train_score']), np.mean(scores['test_score']))
# Out:
# 1.0 0.8666666666666666

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)

# %%
rf.feature_importances_
# Out:
# array([0.03730705, 0.03826355, 0.06057344, 0.04760346, 0.0892165 ,
#        0.07276487, 0.13096579, 0.06878146, 0.04385315, 0.04050079,
#        0.19762382, 0.08259069, 0.08995544])

# %%
n_features = X.shape[1]
plt.barh(np.arange(n_features), sorted(rf.feature_importances_), align='center')
plt.yticks(np.arange(n_features), X.columns)
plt.xlabel('Random Forest Feature Importances')
plt.ylabel('Feature')
plt.ylim(-1, n_features)
# Out:
# (-1.0, 13.0)

# %% [markdown]
# 생존률 중 5년 생존률 중요도가 가장 높음 > 5년 생존률만 사용

# %%
X = X.drop(['신생 1  생존률', '신생 3  생존률', '신생 5  생존률', '1  생존률', '3  생존률'], axis=1)

# %%
corr = X.corr()
plt.figure(figsize=(6,6))
ax = sns.heatmap(corr, annot=True, cmap='gray')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 최근 30년 평균 영업기간 > 전체적으로 높은 상관계수 > 제거

# %%
X = X.drop(['최근 30년  평균영업기간'], axis=1)

# %%
corr = X.corr()
plt.figure(figsize=(6,6))
ax = sns.heatmap(corr, annot=True, cmap='gray')
plt.show()

# %% [markdown]
# '임대료', '직장 인구 대비 주거 인구' 높은 상관관계

# %%
X_scaled = StandardScaler().fit_transform(X)

data_train = X_scaled[:450]
target_train = Y[:450]
data_test = X_scaled[450:]
target_test = Y[450:]

x_train, x_val, y_train, y_val = train_test_split(data_train, target_train, test_size=0.2)

# %%
rf = RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)
scores = cross_validate(rf, x_train, y_train, return_train_score=True, n_jobs=-1)
print(np.mean(scores['train_score']), np.mean(scores['test_score']))
# Out:
# 1.0 0.8166666666666667

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)

# %%
rf.feature_importances_
# Out:
# array([0.10234449, 0.09515414, 0.21551667, 0.11722951, 0.11106365,
#        0.15840572, 0.20028582])

# %%
n_features = X.shape[1]
plt.barh(np.arange(n_features), sorted(rf.feature_importances_), align='center')
plt.yticks(np.arange(n_features), X.columns)
plt.xlabel('Random Forest Feature Importances')
plt.ylabel('Feature')
plt.ylim(-1, n_features)
# Out:
# (-1.0, 7.0)

# %% [markdown]
# 변수 중요도 낮은 '임대료' 제거

# %%
X = X.drop(['임대료'], axis=1)

# %%
corr = X.corr()
plt.figure(figsize=(6,6))
ax = sns.heatmap(corr, annot=True, cmap='gray')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"] = X.columns
vif
# Out:
#    VIF Factor        Features
# 0   62.525908             개업률
# 1  101.524893             폐업률
# 2   95.331630          5  생존률
# 3  243.685342  최근 10년  평균영업기간
# 4   50.241065     프랜차이즈 점포 비율
# 5    2.285237  직장 인구 대비 주거 인구

# %%
X.columns
# Out:
# Index(['개업률', '폐업률', '5  생존률', '최근 10년  평균영업기간', '프랜차이즈 점포 비율',
#        '직장 인구 대비 주거 인구'],
#       dtype='object')
